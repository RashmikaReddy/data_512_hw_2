# %%
import os, json, time, datetime, urllib, re, requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Creating a df of politicans
politicians_df = pd.read_csv('/content/drive/My Drive/DATA_512_HW_2/Datasets/us_cities_by_state_SEPT.2023.csv')
population_df = pd.read_excel('/content/drive/My Drive/DATA_512_HW_2/Datasets/NST-EST2022.xlsx')

# %%
politicians_df.head(10)
# Out:
#      state               page_title  \
# 0  Alabama       Abbeville, Alabama
# 1  Alabama      Adamsville, Alabama
# 2  Alabama         Addison, Alabama
# 3  Alabama           Akron, Alabama
# 4  Alabama       Alabaster, Alabama
# 5  Alabama     Albertville, Alabama
# 6  Alabama  Alexander City, Alabama
# 7  Alabama      Aliceville, Alabama
# 8  Alabama         Allgood, Alabama
# 9  Alabama         Altoona, Alabama
#
#                                                  url
# 0   https://en.wikipedia.org/wiki/Abbeville,_Alabama
# 1  https://en.wikipedia.org/wiki/Adamsville,_Alabama
# 2     https://en.wikipedia.org/wiki/Addison,_Alabama
# 3       https://en.wikipedia.org/wiki/Akron,_Alabama
# 4   https://en.wikipedia.org/wiki/Alabaster,_Alabama
# 5  https://en.wikipedia.org/wiki/Albertville,_Ala...
# 6  https://en.wikipedia.org/wiki/Alexander_City,_...
# 7  https://en.wikipedia.org/wiki/Aliceville,_Alabama
# 8     https://en.wikipedia.org/wiki/Allgood,_Alabama
# 9     https://en.wikipedia.org/wiki/Altoona,_Alabama

# %%
population_df.head()
# Out:
#          State  2022 Population
# 0     .Alabama          5074296
# 1      .Alaska           733583
# 2     .Arizona          7359197
# 3    .Arkansas          3045637
# 4  .California         39029342

# %% [markdown]
# Validating and cleaning data to handle inconsistencies

# %%
politicians_df.describe()
# Out:
#                state              page_title  \
# count          22157                   22157
# unique            48                   21519
# top     Pennsylvania  County (United States)
# freq            2556                       7
#
#                                                       url
# count                                               22157
# unique                                              21519
# top     https://en.wikipedia.org/wiki/County_(United_S...
# freq                                                    7

# %%
print(f'Politicians data shape: {politicians_df.shape}')
print(f'Politicians data duplicate record count: {politicians_df[politicians_df.duplicated()].shape}')
print(f'Politicians data duplicates (based on article url only) count: {politicians_df[politicians_df.duplicated(subset=["url"])].shape}')
# Out:
# Politicians data shape: (22157, 3)
# Politicians data duplicate record count: (632, 3)
# Politicians data duplicates (based on article url only) count: (638, 3)

# %%
# Considering only the last entry from the politicians data to eliminate duplicates
politicians_df = politicians_df[-politicians_df.duplicated()]

# Politicians data post clean up
print(f'Politicians data shape: {politicians_df.shape}')
print(f'Politicians data duplicate record count: {politicians_df[politicians_df.duplicated()].shape[0]}')
# Out:
# Politicians data shape: (21525, 3)
# Politicians data duplicate record count: 0

# %%
ARTICLE_TITLES = politicians_df['page_title']
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': 'voreddy@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2023',
}

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None,
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT,
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):

    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# In the second step, you'll need to acquire estimated quality ratings for articles in the Wikipedia dataset using a machine learning system known as ORES (no longer an acronym). These ratings can be categorized from excellent to poor, ranging from FA (Featured article) to Stub (Stub-class article). The process includes:
#
# a) Going through each line in the "politicians_by_country.SEPT.2023.csv" file.
# b) Requesting page information to access the current page revision.
# c) Submitting a request to ORES with the page's title and the current revision ID to receive the anticipated quality rating for each article.

# %%
all_pages = []
for article in ARTICLE_TITLES:
  info = request_pageinfo_per_article(article)
  for name in info['query']['pages']:
    all_pages.append(info['query']['pages'][name])

# %%
with open('/content/drive/My Drive/DATA_512_HW_2/processed_data/city_data.json', 'w') as f:
    json.dump(all_pages, f)
    print(f'Saved the file to {f.name}')
# Out:
# Saved the file to /content/drive/My Drive/DATA_512_HW_2/processed_data/city_data.json

# %%
cities = pd.read_json('/content/drive/My Drive/DATA_512_HW_2/processed_data/city_data.json')
title_ids = pd.Series(cities.lastrevid.values,index=cities.title).to_dict()

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (60.0/5000.0)-API_LATENCY_ASSUMED

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "voreddy@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2023",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
# REQUEST_HEADER_PARAMS_TEMPLATE = {
#     'email_address' : "voreddy@uw.edu",         # your email address should go here
#     'access_token'  : "xxxx"
# }

REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "voreddy@uw.edu",         # your email address should go here
    'access_token'  : "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....IeV-rxd_-f4EBUeDVARLoVI_u-J8tzI6HhK5sXCyC5A6-6Vih6A3Yff6VurohjOYv0Aswh8M8dU6zkScaHWA29EE03r9B_OmzUMfu2AdDVBY9OB7Z1q-qvrHCfGE_hDuLPtFGoc1H4jcXlyKasY0YKJ9w3vQ8E3uzgY5XWOwVGf0R6E3dDHPxrChmPrW9c1570g91QCjuXvDLAP62v5h0z-kJJZ1WHm9Opy-Cbic8EKsdcMYYMudthYPH6l08xFBpQIjytNKbOI-8WlCF7jDeeeXxdiSrSTBvusqaY4G1Boo9YGCTqVXjibYrNSOad9p5STjs1LktpBbLkDjAq5HIDLyGNEzOwdlOvvArqTvMMdZctT4dq5BKjXoGa5gX3c6Ee4I2ctxVvC8o673meHSGd9fAFbHyUe2hhqhMB6YPt-q480Pa_11b0NeeC_W5ENh_vKFGMwXshQB96q84SgehDGUyGz2lXBj2l3P1lqOxaeurX3CKzZN6W6BRh_3NHeo3xlfFlPQVS6pa2UDcZGG9I9jO8pRXJVOaLW9HDsGoF7LkzOeyVjyEx2MHu7YZeEMrDcIi5RsqlbeaNideAZ0KeBdnimKWQ0836Z0o_VLC4MlyLVUbbzQ3LywJLBK6wgrOvNGvolDyfLy3w3q2pDnUIfgLQ3PMFR729F7LTTkCxw"          # the access token you create will need to go here
}

#
#    A dictionary of English Wikipedia article titles (keys) and sample revision IDs that can be used for this ORES scoring example
#
ARTICLE_REVISIONS = title_ids

#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#
#    These are used later - defined here so they, at least, have empty values
#
USERNAME = ""
ACCESS_TOKEN = ""
#

# %%
# !pip install apikey
# Out:
# Collecting apikey
#   Downloading apikey-0.2.4.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apikey
#   Building wheel for apikey (setup.py) ... done
#   Created wheel for apikey: filename=apikey-0.2.4-py3-none-any.whl size=6671 sha256=d19ded2c68c3916848a178ae654c27fa95493fd2d35d14f6aab9641e6170b305
#   Stored in directory: /root/.cache/pip/wheels/d0/b2/c9/a4400b26c52c13f16c796d15694407a8c610a3098b9e886651
# Successfully built apikey
# Installing collected packages: apikey
# Successfully installed apikey-0.2.4

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT,
                                   model_name = API_ORES_EN_QUALITY_MODEL,
                                   request_data = ORES_REQUEST_DATA_TEMPLATE,
                                   header_format = REQUEST_HEADER_TEMPLATE,
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):

    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token

    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")

    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)

    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)
            # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#
#   Which article - the key for the article dictionary defined above
article_title = "Harmony, Indiana"
#
print(f"Getting LiftWing ORES scores for '{article_title}' with revid: {ARTICLE_REVISIONS[article_title]:d}")
#
#    Make the call, just pass in the article revision ID, email address, and access token
score = request_ores_score_per_article(article_revid=ARTICLE_REVISIONS[article_title],
                                       email_address="voreddy@uw.edu",
                                       access_token=ACCESS_TOKEN)
#
#    Output the result
try:
  for id in score['enwiki']['scores']:
except:
  print("No data for ",article_title)
#

# %%
quality = {}
for article_title in ARTICLE_REVISIONS:
  print(f"Getting LiftWing ORES scores for '{article_title}' with revid: {ARTICLE_REVISIONS[article_title]:d}")
  score = request_ores_score_per_article(article_revid=ARTICLE_REVISIONS[article_title],
                                       email_address="voreddy@uw.edu",
                                       access_token=ACCESS_TOKEN)
  for id in score['enwiki']['scores']:
    pred = score['enwiki']['scores'][id]['articlequality']['score']['prediction']
    quality[article_title] = pred
# Out:
# Streaming output truncated to the last 5000 lines.
# Getting LiftWing ORES scores for 'Floyd, Iowa' with revid: 1165747026
# Getting LiftWing ORES scores for 'Fonda, Iowa' with revid: 1165747057
# Getting LiftWing ORES scores for 'Pocahontas County, Iowa' with revid: 1160185843
# Getting LiftWing ORES scores for 'Fontanelle, Iowa' with revid: 1165747062
# Getting LiftWing ORES scores for 'Forest City, Iowa' with revid: 1171091982
# Getting LiftWing ORES scores for 'Fort Atkinson, Iowa' with revid: 1165747182
# Getting LiftWing ORES scores for 'Fort Dodge, Iowa' with revid: 1176015674
# Getting LiftWing ORES scores for 'Fort Madison, Iowa' with revid: 1165747198
# Getting LiftWing ORES scores for 'Fostoria, Iowa' with revid: 1165747259
# Getting LiftWing ORES scores for 'Franklin, Iowa' with revid: 1165747331
# Getting LiftWing ORES scores for 'Fraser, Iowa' with revid: 1165747368
# Getting LiftWing ORES scores for 'Fredericksburg, Iowa' with revid: 1165747373
# Getting LiftWing ORES scores for 'Frederika, Iowa' with revid: 1165747378
# Getting LiftWing ORES scores for 'Fredonia, Iowa' with revid: 1165747386
# Getting LiftWing ORES scores for 'Fremont, Iowa' with revid: 1165747427
# Getting LiftWing ORES scores for 'Fruitland, Iowa' with revid: 1165747498
# Getting LiftWing ORES scores for 'Galt, Iowa' with revid: 1165747606
# Getting LiftWing ORES scores for 'Galva, Iowa' with revid: 1165747623
# Getting LiftWing ORES scores for 'Garber, Iowa' with revid: 1165747644
# Getting LiftWing ORES scores for 'Garden Grove, Iowa' with revid: 1176099251
# Getting LiftWing ORES scores for 'Garnavillo, Iowa' with revid: 1165747700
# Getting LiftWing ORES scores for 'Garner, Iowa' with revid: 1173207298
# Getting LiftWing ORES scores for 'Garrison, Iowa' with revid: 1165747714
# Getting LiftWing ORES scores for 'Garwin, Iowa' with revid: 1165747729
# Getting LiftWing ORES scores for 'Geneva, Iowa' with revid: 1165747816
# Getting LiftWing ORES scores for 'George, Iowa' with revid: 1166472293
# Getting LiftWing ORES scores for 'Gibson, Iowa' with revid: 1165747931
# Getting LiftWing ORES scores for 'Gilbert, Iowa' with revid: 1165747944
# Getting LiftWing ORES scores for 'Gilbertville, Iowa' with revid: 1165747956
# Getting LiftWing ORES scores for 'Gillett Grove, Iowa' with revid: 1165747965
# Getting LiftWing ORES scores for 'Gilman, Iowa' with revid: 1165862129
# Getting LiftWing ORES scores for 'Gilmore City, Iowa' with revid: 1167269961
# Getting LiftWing ORES scores for 'Gladbrook, Iowa' with revid: 1168105273
# Getting LiftWing ORES scores for 'Glenwood, Iowa' with revid: 1165748133
# Getting LiftWing ORES scores for 'Glidden, Iowa' with revid: 1165748137
# Getting LiftWing ORES scores for 'Goldfield, Iowa' with revid: 1165748178
# Getting LiftWing ORES scores for 'Goodell, Iowa' with revid: 1165748204
# Getting LiftWing ORES scores for 'Goose Lake, Iowa' with revid: 1165748250
# Getting LiftWing ORES scores for 'Gowrie, Iowa' with revid: 1167719492
# Getting LiftWing ORES scores for 'Graettinger, Iowa' with revid: 1165748321
# Getting LiftWing ORES scores for 'Graf, Iowa' with revid: 1165748326
# Getting LiftWing ORES scores for 'Grafton, Iowa' with revid: 1165748344
# Getting LiftWing ORES scores for 'Grand Junction, Iowa' with revid: 1165748398
# Getting LiftWing ORES scores for 'Grand Mound, Iowa' with revid: 1165748409
# Getting LiftWing ORES scores for 'Grand River, Iowa' with revid: 1165748417
# Getting LiftWing ORES scores for 'Grandview, Iowa' with revid: 1165748458
# Getting LiftWing ORES scores for 'Granger, Iowa' with revid: 1165748476
# Getting LiftWing ORES scores for 'Grant, Iowa' with revid: 1165748528
# Getting LiftWing ORES scores for 'Granville, Iowa' with revid: 1165748552
# Getting LiftWing ORES scores for 'Gravity, Iowa' with revid: 1165748580
# Getting LiftWing ORES scores for 'Gray, Iowa' with revid: 1165748588
# Getting LiftWing ORES scores for 'Greeley, Iowa' with revid: 1165748618
# Getting LiftWing ORES scores for 'Greene, Iowa' with revid: 1165748689
# Getting LiftWing ORES scores for 'Greenfield, Iowa' with revid: 1165748700
# Getting LiftWing ORES scores for 'Greenville, Iowa' with revid: 1165748753
# Getting LiftWing ORES scores for 'Grimes, Iowa' with revid: 1172724113
# Getting LiftWing ORES scores for 'Grinnell, Iowa' with revid: 1173861915
# Getting LiftWing ORES scores for 'Griswold, Iowa' with revid: 1165748841
# Getting LiftWing ORES scores for 'Grundy Center, Iowa' with revid: 1165748885
# Getting LiftWing ORES scores for 'Gruver, Iowa' with revid: 1165748888
# Getting LiftWing ORES scores for 'Guernsey, Iowa' with revid: 1172989811
# Getting LiftWing ORES scores for 'Guthrie Center, Iowa' with revid: 1165748938
# Getting LiftWing ORES scores for 'Guttenberg, Iowa' with revid: 1165748950
# Getting LiftWing ORES scores for 'Halbur, Iowa' with revid: 1165748992
# Getting LiftWing ORES scores for 'Hamburg, Iowa' with revid: 1165749062
# Getting LiftWing ORES scores for 'Hamilton, Iowa' with revid: 1165749080
# Getting LiftWing ORES scores for 'Hampton, Iowa' with revid: 1165749130
# Getting LiftWing ORES scores for 'Hancock, Iowa' with revid: 1158244580
# Getting LiftWing ORES scores for 'Hanlontown, Iowa' with revid: 1165749152
# Getting LiftWing ORES scores for 'Hansell, Iowa' with revid: 1165749176
# Getting LiftWing ORES scores for 'Harcourt, Iowa' with revid: 1165749193
# Getting LiftWing ORES scores for 'Hardy, Iowa' with revid: 1165749224
# Getting LiftWing ORES scores for 'Harlan, Iowa' with revid: 1177325060
# Getting LiftWing ORES scores for 'Harper, Iowa' with revid: 1165749243
# Getting LiftWing ORES scores for 'Harpers Ferry, Iowa' with revid: 1165749247
# Getting LiftWing ORES scores for 'Allamakee County, Iowa' with revid: 1160187369
# Getting LiftWing ORES scores for 'Harris, Iowa' with revid: 1165749265
# Getting LiftWing ORES scores for 'Hartford, Iowa' with revid: 1165749310
# Getting LiftWing ORES scores for 'Hartley, Iowa' with revid: 1165749334
# Getting LiftWing ORES scores for 'Hartwick, Iowa' with revid: 1165749350
# Getting LiftWing ORES scores for 'Harvey, Iowa' with revid: 1165749363
# Getting LiftWing ORES scores for 'Hastings, Iowa' with revid: 1165749389
# Getting LiftWing ORES scores for 'Havelock, Iowa' with revid: 1165749420
# Getting LiftWing ORES scores for 'Haverhill, Iowa' with revid: 1165749434
# Getting LiftWing ORES scores for 'Hawarden, Iowa' with revid: 1139508344
# Getting LiftWing ORES scores for 'Hawkeye, Iowa' with revid: 1173861904
# Getting LiftWing ORES scores for 'Hayesville, Iowa' with revid: 1165749489
# Getting LiftWing ORES scores for 'Hazleton, Iowa' with revid: 1165749559
# Getting LiftWing ORES scores for 'Hedrick, Iowa' with revid: 1165749663
# Getting LiftWing ORES scores for 'Henderson, Iowa' with revid: 1165749720
# Getting LiftWing ORES scores for 'Hepburn, Iowa' with revid: 1177683630
# Getting LiftWing ORES scores for 'Hiawatha, Iowa' with revid: 1172728966
# Getting LiftWing ORES scores for 'Hills, Iowa' with revid: 1165750043
# Getting LiftWing ORES scores for 'Hillsboro, Iowa' with revid: 1165750055
# Getting LiftWing ORES scores for 'Hinton, Iowa' with revid: 1165750113
# Getting LiftWing ORES scores for 'Holland, Iowa' with revid: 1165750209
# Getting LiftWing ORES scores for 'Holstein, Iowa' with revid: 1165750262
# Getting LiftWing ORES scores for 'Holy Cross, Iowa' with revid: 1165750287
# Getting LiftWing ORES scores for 'Hopkinton, Iowa' with revid: 1165750377
# Getting LiftWing ORES scores for 'Hornick, Iowa' with revid: 1165750412
# Getting LiftWing ORES scores for 'Hospers, Iowa' with revid: 1165750438
# Getting LiftWing ORES scores for 'Houghton, Iowa' with revid: 1165750444
# Getting LiftWing ORES scores for 'Hubbard, Iowa' with revid: 1165750503
# Getting LiftWing ORES scores for 'Hudson, Iowa' with revid: 1165750523
# Getting LiftWing ORES scores for 'Hull, Iowa' with revid: 1175718126
# Getting LiftWing ORES scores for 'Humboldt, Iowa' with revid: 1165750583
# Getting LiftWing ORES scores for 'Humeston, Iowa' with revid: 1165750597
# Getting LiftWing ORES scores for 'Huxley, Iowa' with revid: 1165750716
# Getting LiftWing ORES scores for 'Ida Grove, Iowa' with revid: 1165750746
# Getting LiftWing ORES scores for 'Imogene, Iowa' with revid: 1177683163
# Getting LiftWing ORES scores for 'Independence, Iowa' with revid: 1176963033
# Getting LiftWing ORES scores for 'Indianola, Iowa' with revid: 1172137585
# Getting LiftWing ORES scores for 'Inwood, Iowa' with revid: 1165750849
# Getting LiftWing ORES scores for 'Ionia, Iowa' with revid: 1165750873
# Getting LiftWing ORES scores for 'Iowa City, Iowa' with revid: 1179868852
# Getting LiftWing ORES scores for 'Iowa Falls, Iowa' with revid: 1165750880
# Getting LiftWing ORES scores for 'Ireton, Iowa' with revid: 1165750896
# Getting LiftWing ORES scores for 'Irwin, Iowa' with revid: 1165750930
# Getting LiftWing ORES scores for 'Jackson Junction, Iowa' with revid: 1172733517
# Getting LiftWing ORES scores for 'Jamaica, Iowa' with revid: 1165751041
# Getting LiftWing ORES scores for 'Janesville, Iowa' with revid: 1175846909
# Getting LiftWing ORES scores for 'Jefferson, Iowa' with revid: 1158102102
# Getting LiftWing ORES scores for 'Jesup, Iowa' with revid: 1173079894
# Getting LiftWing ORES scores for 'Jewell Junction, Iowa' with revid: 1165751198
# Getting LiftWing ORES scores for 'Johnston, Iowa' with revid: 1178794334
# Getting LiftWing ORES scores for 'Joice, Iowa' with revid: 1165751251
# Getting LiftWing ORES scores for 'Jolley, Iowa' with revid: 1165751253
# Getting LiftWing ORES scores for 'Kalona, Iowa' with revid: 1179618168
# Getting LiftWing ORES scores for 'Kamrar, Iowa' with revid: 1165751843
# Getting LiftWing ORES scores for 'Kanawha, Iowa' with revid: 1168605447
# Getting LiftWing ORES scores for 'Kellerton, Iowa' with revid: 1165751943
# Getting LiftWing ORES scores for 'Kelley, Iowa' with revid: 1153490990
# Getting LiftWing ORES scores for 'Kellogg, Iowa' with revid: 1165751957
# Getting LiftWing ORES scores for 'Kensett, Iowa' with revid: 1165752039
# Getting LiftWing ORES scores for 'Keokuk, Iowa' with revid: 1170378762
# Getting LiftWing ORES scores for 'Keomah Village, Iowa' with revid: 1165752068
# Getting LiftWing ORES scores for 'Keosauqua, Iowa' with revid: 1165752071
# Getting LiftWing ORES scores for 'Keota, Iowa' with revid: 1174127424
# Getting LiftWing ORES scores for 'Keswick, Iowa' with revid: 1165752100
# Getting LiftWing ORES scores for 'Keystone, Iowa' with revid: 1178304388
# Getting LiftWing ORES scores for 'Kimballton, Iowa' with revid: 1165752194
# Getting LiftWing ORES scores for 'Kingsley, Iowa' with revid: 1179637082
# Getting LiftWing ORES scores for 'Kinross, Iowa' with revid: 1158900242
# Getting LiftWing ORES scores for 'Kirkman, Iowa' with revid: 1165752308
# Getting LiftWing ORES scores for 'Kirkville, Iowa' with revid: 1165752311
# Getting LiftWing ORES scores for 'Kiron, Iowa' with revid: 1165752317
# Getting LiftWing ORES scores for 'Klemme, Iowa' with revid: 1165752346
# Getting LiftWing ORES scores for 'Knierim, Iowa' with revid: 1165752350
# Getting LiftWing ORES scores for 'Knoxville, Iowa' with revid: 1175572152
# Getting LiftWing ORES scores for 'La Motte, Iowa' with revid: 1165752521
# Getting LiftWing ORES scores for 'La Porte City, Iowa' with revid: 1165752538
# Getting LiftWing ORES scores for 'Lacona, Iowa' with revid: 1165752607
# Getting LiftWing ORES scores for 'Ladora, Iowa' with revid: 1165752620
# Getting LiftWing ORES scores for 'Iowa County, Iowa' with revid: 1160186010
# Getting LiftWing ORES scores for 'Lake City, Iowa' with revid: 1175696351
# Getting LiftWing ORES scores for 'Lake Mills, Iowa' with revid: 1165752734
# Getting LiftWing ORES scores for 'Lake Park, Iowa' with revid: 1165752752
# Getting LiftWing ORES scores for 'Lake View, Iowa' with revid: 1128075154
# Getting LiftWing ORES scores for 'Lakeside, Iowa' with revid: 1165752843
# Getting LiftWing ORES scores for 'Lakota, Iowa' with revid: 1168606147
# Getting LiftWing ORES scores for 'Lambs Grove, Iowa' with revid: 1165752890
# Getting LiftWing ORES scores for 'Lamoni, Iowa' with revid: 1177684017
# Getting LiftWing ORES scores for 'Lamont, Iowa' with revid: 1165752917
# Getting LiftWing ORES scores for 'Lanesboro, Iowa' with revid: 1165752960
# Getting LiftWing ORES scores for 'Lansing, Iowa' with revid: 1173246123
# Getting LiftWing ORES scores for 'Larchwood, Iowa' with revid: 1168607026
# Getting LiftWing ORES scores for 'Larrabee, Iowa' with revid: 1165889274
# Getting LiftWing ORES scores for 'Latimer, Iowa' with revid: 1165889316
# Getting LiftWing ORES scores for 'Laurel, Iowa' with revid: 1165889342
# Getting LiftWing ORES scores for 'Laurens, Iowa' with revid: 1165889391
# Getting LiftWing ORES scores for 'Lawler, Iowa' with revid: 1165889453
# Getting LiftWing ORES scores for 'Lawton, Iowa' with revid: 1165889561
# Getting LiftWing ORES scores for 'Le Claire, Iowa' with revid: 1093522921
# Getting LiftWing ORES scores for 'Le Grand, Iowa' with revid: 1165889593
# Getting LiftWing ORES scores for 'Le Mars, Iowa' with revid: 1176642204
# Getting LiftWing ORES scores for 'Le Roy, Iowa' with revid: 1165889602
# Getting LiftWing ORES scores for 'Ledyard, Iowa' with revid: 1165889811
# Getting LiftWing ORES scores for 'Lehigh, Iowa' with revid: 1153652666
# Getting LiftWing ORES scores for 'Leighton, Iowa' with revid: 1165889872
# Getting LiftWing ORES scores for 'Leland, Iowa' with revid: 1165889902
# Getting LiftWing ORES scores for 'Lenox, Iowa' with revid: 1165889941
# Getting LiftWing ORES scores for 'Leon, Iowa' with revid: 1176246816
# Getting LiftWing ORES scores for 'Lester, Iowa' with revid: 1165890034
# Getting LiftWing ORES scores for 'Letts, Iowa' with revid: 1165890039
# Getting LiftWing ORES scores for 'Lewis, Iowa' with revid: 1165890052
# Getting LiftWing ORES scores for 'Libertyville, Iowa' with revid: 1176415969
# Getting LiftWing ORES scores for 'Lidderdale, Iowa' with revid: 1165890264
# Getting LiftWing ORES scores for 'Lime Springs, Iowa' with revid: 1165890308
# Getting LiftWing ORES scores for 'Lincoln, Iowa' with revid: 1165890332
# Getting LiftWing ORES scores for 'Linden, Iowa' with revid: 1158066830
# Getting LiftWing ORES scores for 'Lineville, Iowa' with revid: 1165890467
# Getting LiftWing ORES scores for 'Linn Grove, Iowa' with revid: 1165890478
# Getting LiftWing ORES scores for 'Lisbon, Iowa' with revid: 1165890543
# Getting LiftWing ORES scores for 'Liscomb, Iowa' with revid: 1165890552
# Getting LiftWing ORES scores for 'Little Rock, Iowa' with revid: 1165891086
# Getting LiftWing ORES scores for 'Little Sioux, Iowa' with revid: 1165891089
# Getting LiftWing ORES scores for 'Livermore, Iowa' with revid: 1165891113
# Getting LiftWing ORES scores for 'Lockridge, Iowa' with revid: 1165891155
# Getting LiftWing ORES scores for 'Logan, Iowa' with revid: 1165891172
# Getting LiftWing ORES scores for 'Lohrville, Iowa' with revid: 1165891201
# Getting LiftWing ORES scores for 'Lone Rock, Iowa' with revid: 1165891234
# Getting LiftWing ORES scores for 'Lone Tree, Iowa' with revid: 1165891252
# Getting LiftWing ORES scores for 'Long Grove, Iowa' with revid: 1155083446
# Getting LiftWing ORES scores for 'Lorimor, Iowa' with revid: 1165891371
# Getting LiftWing ORES scores for 'Lost Nation, Iowa' with revid: 1175705132
# Getting LiftWing ORES scores for 'Lovilia, Iowa' with revid: 1165891474
# Getting LiftWing ORES scores for 'Low Moor, Iowa' with revid: 1165891484
# Getting LiftWing ORES scores for 'Lowden, Iowa' with revid: 1165891488
# Getting LiftWing ORES scores for 'Lu Verne, Iowa' with revid: 1165891543
# Getting LiftWing ORES scores for 'Luana, Iowa' with revid: 1165891548
# Getting LiftWing ORES scores for 'Lucas, Iowa' with revid: 1158665396
# Getting LiftWing ORES scores for 'Luther, Iowa' with revid: 1165891624
# Getting LiftWing ORES scores for 'Luxemburg, Iowa' with revid: 1165891643
# Getting LiftWing ORES scores for 'Luzerne, Iowa' with revid: 1165891650
# Getting LiftWing ORES scores for 'Lynnville, Iowa' with revid: 1165891698
# Getting LiftWing ORES scores for 'Lytton, Iowa' with revid: 1165891713
# Getting LiftWing ORES scores for 'Macedonia, Iowa' with revid: 1165891726
# Getting LiftWing ORES scores for 'Macksburg, Iowa' with revid: 1165891738
# Getting LiftWing ORES scores for 'Madrid, Iowa' with revid: 1167629321
# Getting LiftWing ORES scores for 'Magnolia, Iowa' with revid: 1165891828
# Getting LiftWing ORES scores for 'Maharishi Vedic City, Iowa' with revid: 1170900656
# Getting LiftWing ORES scores for 'Malcom, Iowa' with revid: 1165891878
# Getting LiftWing ORES scores for 'Mallard, Iowa' with revid: 1165891888
# Getting LiftWing ORES scores for 'Maloy, Iowa' with revid: 1165891893
# Getting LiftWing ORES scores for 'Malvern, Iowa' with revid: 1179094243
# Getting LiftWing ORES scores for 'Manchester, Iowa' with revid: 1151551141
# Getting LiftWing ORES scores for 'Manilla, Iowa' with revid: 1167465756
# Getting LiftWing ORES scores for 'Manly, Iowa' with revid: 1165892000
# Getting LiftWing ORES scores for 'Manning, Iowa' with revid: 1165892001
# Getting LiftWing ORES scores for 'Manson, Iowa' with revid: 1165892043
# Getting LiftWing ORES scores for 'Mapleton, Iowa' with revid: 1165892085
# Getting LiftWing ORES scores for 'Maquoketa, Iowa' with revid: 1177768984
# Getting LiftWing ORES scores for 'Marathon, Iowa' with revid: 1173438471
# Getting LiftWing ORES scores for 'Marble Rock, Iowa' with revid: 1116179154
# Getting LiftWing ORES scores for 'Marcus, Iowa' with revid: 1165892158
# Getting LiftWing ORES scores for 'Marengo, Iowa' with revid: 1177031280
# Getting LiftWing ORES scores for 'Marion, Iowa' with revid: 1178794172
# Getting LiftWing ORES scores for 'Marne, Iowa' with revid: 1165892374
# Getting LiftWing ORES scores for 'Marquette, Iowa' with revid: 1166522863
# Getting LiftWing ORES scores for 'Marshalltown, Iowa' with revid: 1177331226
# Getting LiftWing ORES scores for 'Martelle, Iowa' with revid: 1165892480
# Getting LiftWing ORES scores for 'Martensdale, Iowa' with revid: 1165892483
# Getting LiftWing ORES scores for 'Martinsburg, Iowa' with revid: 1165892514
# Getting LiftWing ORES scores for 'Marysville, Iowa' with revid: 1165892548
# Getting LiftWing ORES scores for 'Mason City, Iowa' with revid: 1173538364
# Getting LiftWing ORES scores for 'Masonville, Iowa' with revid: 1165892591
# Getting LiftWing ORES scores for 'Massena, Iowa' with revid: 1172457863
# Getting LiftWing ORES scores for 'Matlock, Iowa' with revid: 1165892606
# Getting LiftWing ORES scores for 'Maurice, Iowa' with revid: 1165892643
# Getting LiftWing ORES scores for 'Maxwell, Iowa' with revid: 1165892656
# Getting LiftWing ORES scores for 'Maynard, Iowa' with revid: 1165892678
# Getting LiftWing ORES scores for 'Maysville, Iowa' with revid: 1155083503
# Getting LiftWing ORES scores for 'McCallsburg, Iowa' with revid: 1165892717
# Getting LiftWing ORES scores for 'McCausland, Iowa' with revid: 1177310326
# Getting LiftWing ORES scores for 'McClelland, Iowa' with revid: 1165892751
# Getting LiftWing ORES scores for 'McGregor, Iowa' with revid: 1165892812
# Getting LiftWing ORES scores for 'McIntire, Iowa' with revid: 1165892831
# Getting LiftWing ORES scores for 'Mechanicsville, Iowa' with revid: 1165892994
# Getting LiftWing ORES scores for 'Mediapolis, Iowa' with revid: 1165893013
# Getting LiftWing ORES scores for 'Melbourne, Iowa' with revid: 1165893090
# Getting LiftWing ORES scores for 'Melcher-Dallas, Iowa' with revid: 1165893097
# Getting LiftWing ORES scores for 'Melrose, Iowa' with revid: 1165893108
# Getting LiftWing ORES scores for 'Melvin, Iowa' with revid: 1165893129
# Getting LiftWing ORES scores for 'Menlo, Iowa' with revid: 1165893190
# Getting LiftWing ORES scores for 'Meriden, Iowa' with revid: 1165893228
# Getting LiftWing ORES scores for 'Merrill, Iowa' with revid: 1165893249
# Getting LiftWing ORES scores for 'Meservey, Iowa' with revid: 1165893266
# Getting LiftWing ORES scores for 'Middletown, Iowa' with revid: 1176416087
# Getting LiftWing ORES scores for 'Miles, Iowa' with revid: 1165893458
# Getting LiftWing ORES scores for 'Milford, Iowa' with revid: 1165893480
# Getting LiftWing ORES scores for 'Millersburg, Iowa' with revid: 1165893526
# Getting LiftWing ORES scores for 'Millerton, Iowa' with revid: 1165893536
# Getting LiftWing ORES scores for 'Milo, Iowa' with revid: 1165893562
# Getting LiftWing ORES scores for 'Milton, Iowa' with revid: 1165893578
# Getting LiftWing ORES scores for 'Minburn, Iowa' with revid: 1165893611
# Getting LiftWing ORES scores for 'Minden, Iowa' with revid: 1165893622
# Getting LiftWing ORES scores for 'Mingo, Iowa' with revid: 1165893660
# Getting LiftWing ORES scores for 'Missouri Valley, Iowa' with revid: 1176992240
# Getting LiftWing ORES scores for 'Mitchell, Iowa' with revid: 1165893777
# Getting LiftWing ORES scores for 'Mitchellville, Iowa' with revid: 1165893803
# Getting LiftWing ORES scores for 'Modale, Iowa' with revid: 1165893846
# Getting LiftWing ORES scores for 'Mondamin, Iowa' with revid: 1165893903
# Getting LiftWing ORES scores for 'Monmouth, Iowa' with revid: 1165893924
# Getting LiftWing ORES scores for 'Monona, Iowa' with revid: 1165893933
# Getting LiftWing ORES scores for 'Monroe, Iowa' with revid: 1165893960
# Getting LiftWing ORES scores for 'Montezuma, Iowa' with revid: 1178856327
# Getting LiftWing ORES scores for 'Monticello, Iowa' with revid: 1165894083
# Getting LiftWing ORES scores for 'Montour, Iowa' with revid: 1165894106
# Getting LiftWing ORES scores for 'Montrose, Iowa' with revid: 1165894129
# Getting LiftWing ORES scores for 'Moorhead, Iowa' with revid: 1165894182
# Getting LiftWing ORES scores for 'Moorland, Iowa' with revid: 1165894197
# Getting LiftWing ORES scores for 'Moravia, Iowa' with revid: 1170915970
# Getting LiftWing ORES scores for 'Morley, Iowa' with revid: 1165894323
# Getting LiftWing ORES scores for 'Morning Sun, Iowa' with revid: 1165894331
# Getting LiftWing ORES scores for 'Morrison, Iowa' with revid: 1165894362
# Getting LiftWing ORES scores for 'Moulton, Iowa' with revid: 1165894469
# Getting LiftWing ORES scores for 'Mount Auburn, Iowa' with revid: 1165894510
# Getting LiftWing ORES scores for 'Mount Ayr, Iowa' with revid: 1165894516
# Getting LiftWing ORES scores for 'Mount Pleasant, Iowa' with revid: 1177241547
# Getting LiftWing ORES scores for 'Mount Vernon, Iowa' with revid: 1175070348
# Getting LiftWing ORES scores for 'Moville, Iowa' with revid: 1165894688
# Getting LiftWing ORES scores for 'Murray, Iowa' with revid: 1165894806
# Getting LiftWing ORES scores for 'Clarke County, Iowa' with revid: 1160186917
# Getting LiftWing ORES scores for 'Muscatine, Iowa' with revid: 1172972335
# Getting LiftWing ORES scores for 'Mystic, Iowa' with revid: 1158736273
# Getting LiftWing ORES scores for 'Nashua, Iowa' with revid: 1165894910
# Getting LiftWing ORES scores for 'Nemaha, Iowa' with revid: 1165895031
# Getting LiftWing ORES scores for 'Neola, Iowa' with revid: 1165895050
# Getting LiftWing ORES scores for 'Nevada, Iowa' with revid: 1180215064
# Getting LiftWing ORES scores for 'New Albin, Iowa' with revid: 1165895112
# Getting LiftWing ORES scores for 'New Hampton, Iowa' with revid: 1165895221
# Getting LiftWing ORES scores for 'New Hartford, Iowa' with revid: 1165895225
# Getting LiftWing ORES scores for 'New Liberty, Iowa' with revid: 1115665156
# Getting LiftWing ORES scores for 'New London, Iowa' with revid: 1165895280
# Getting LiftWing ORES scores for 'New Market, Iowa' with revid: 1165895303
# Getting LiftWing ORES scores for 'New Providence, Iowa' with revid: 1176509983
# Getting LiftWing ORES scores for 'New Sharon, Iowa' with revid: 1165895347
# Getting LiftWing ORES scores for 'New Vienna, Iowa' with revid: 1165895376
# Getting LiftWing ORES scores for 'New Virginia, Iowa' with revid: 1165895380
# Getting LiftWing ORES scores for 'Newell, Iowa' with revid: 1165895454
# Getting LiftWing ORES scores for 'Newhall, Iowa' with revid: 1165895464
# Getting LiftWing ORES scores for 'Newton, Iowa' with revid: 1168450416
# Getting LiftWing ORES scores for 'Nichols, Iowa' with revid: 1165895549
# Getting LiftWing ORES scores for 'Nodaway, Iowa' with revid: 1165895619
# Getting LiftWing ORES scores for 'Nora Springs, Iowa' with revid: 1165895662
# Getting LiftWing ORES scores for 'North Buena Vista, Iowa' with revid: 1165895762
# Getting LiftWing ORES scores for 'North English, Iowa' with revid: 1165895791
# Getting LiftWing ORES scores for 'North Liberty, Iowa' with revid: 1178794371
# Getting LiftWing ORES scores for 'North Washington, Iowa' with revid: 1165895915
# Getting LiftWing ORES scores for 'Northboro, Iowa' with revid: 1165895923
# Getting LiftWing ORES scores for 'Northwood, Iowa' with revid: 1165895954
# Getting LiftWing ORES scores for 'Norwalk, Iowa' with revid: 1166521116
# Getting LiftWing ORES scores for 'Norway, Iowa' with revid: 1165895999
# Getting LiftWing ORES scores for 'Numa, Iowa' with revid: 1158736650
# Getting LiftWing ORES scores for 'Oakland, Iowa' with revid: 1165896232
# Getting LiftWing ORES scores for 'Oakland Acres, Iowa' with revid: 1165896214
# Getting LiftWing ORES scores for 'Oakville, Iowa' with revid: 1168835224
# Getting LiftWing ORES scores for 'Ocheyedan, Iowa' with revid: 1165896309
# Getting LiftWing ORES scores for 'Odebolt, Iowa' with revid: 1165896345
# Getting LiftWing ORES scores for 'Oelwein, Iowa' with revid: 1165896372
# Getting LiftWing ORES scores for 'Ogden, Iowa' with revid: 1146051902
# Getting LiftWing ORES scores for 'Okoboji, Iowa' with revid: 1165896465
# Getting LiftWing ORES scores for 'Olds, Iowa' with revid: 1165896510
# Getting LiftWing ORES scores for 'Olin, Iowa' with revid: 1165896529
# Getting LiftWing ORES scores for 'Ollie, Iowa' with revid: 1177869359
# Getting LiftWing ORES scores for 'Onawa, Iowa' with revid: 1165896634
# Getting LiftWing ORES scores for 'Onslow, Iowa' with revid: 1165896661
# Getting LiftWing ORES scores for 'Orange City, Iowa' with revid: 1175688109
# Getting LiftWing ORES scores for 'Orchard, Iowa' with revid: 1165896716
# Getting LiftWing ORES scores for 'Orient, Iowa' with revid: 1165896748
# Getting LiftWing ORES scores for 'Orleans, Iowa' with revid: 1165896764
# Getting LiftWing ORES scores for 'Osage, Iowa' with revid: 1177295963
# Getting LiftWing ORES scores for 'Osceola, Iowa' with revid: 1158663305
# Getting LiftWing ORES scores for 'Oskaloosa, Iowa' with revid: 1174053784
# Getting LiftWing ORES scores for 'Ossian, Iowa' with revid: 1165896856
# Getting LiftWing ORES scores for 'Osterdock, Iowa' with revid: 1165896858
# Getting LiftWing ORES scores for 'Otho, Iowa' with revid: 1165896871
# Getting LiftWing ORES scores for 'Oto, Iowa' with revid: 1165896878
# Getting LiftWing ORES scores for 'Ottosen, Iowa' with revid: 1165896898
# Getting LiftWing ORES scores for 'Ottumwa, Iowa' with revid: 1178612341
# Getting LiftWing ORES scores for 'Owasa, Iowa' with revid: 1165896925
# Getting LiftWing ORES scores for 'Oxford, Iowa' with revid: 1165896967
# Getting LiftWing ORES scores for 'Oxford Junction, Iowa' with revid: 1165896954
# Getting LiftWing ORES scores for 'Oyens, Iowa' with revid: 1165896983
# Getting LiftWing ORES scores for 'Pacific Junction, Iowa' with revid: 1176568939
# Getting LiftWing ORES scores for 'Packwood, Iowa' with revid: 1165897013
# Getting LiftWing ORES scores for 'Palmer, Iowa' with revid: 1165897098
# Getting LiftWing ORES scores for 'Palo, Iowa' with revid: 1165897117
# Getting LiftWing ORES scores for 'Panama, Iowa' with revid: 1177829618
# Getting LiftWing ORES scores for 'Panora, Iowa' with revid: 1174666105
# Getting LiftWing ORES scores for 'Panorama Park, Iowa' with revid: 1115664288
# Getting LiftWing ORES scores for 'Parkersburg, Iowa' with revid: 1165897253
# Getting LiftWing ORES scores for 'Parnell, Iowa' with revid: 1176921577
# Getting LiftWing ORES scores for 'Paton, Iowa' with revid: 1165897331
# Getting LiftWing ORES scores for 'Patterson, Iowa' with revid: 1165897340
# Getting LiftWing ORES scores for 'Paullina, Iowa' with revid: 1180046289
# Getting LiftWing ORES scores for 'Pella, Iowa' with revid: 1172338463
# Getting LiftWing ORES scores for 'Peosta, Iowa' with revid: 1165897505
# Getting LiftWing ORES scores for 'Perry, Iowa' with revid: 1177802869
# Getting LiftWing ORES scores for 'Persia, Iowa' with revid: 1165897648
# Getting LiftWing ORES scores for 'Peterson, Iowa' with revid: 1165897689
# Getting LiftWing ORES scores for 'Pierson, Iowa' with revid: 1170364115
# Getting LiftWing ORES scores for 'Pilot Mound, Iowa' with revid: 1165897824
# Getting LiftWing ORES scores for 'Pisgah, Iowa' with revid: 1165897996
# Getting LiftWing ORES scores for 'Plainfield, Iowa' with revid: 1165898032
# Getting LiftWing ORES scores for 'Plano, Iowa' with revid: 1165898100
# Getting LiftWing ORES scores for 'Pleasant Hill, Iowa' with revid: 1172725431
# Getting LiftWing ORES scores for 'Pleasant Plain, Iowa' with revid: 1165898177
# Getting LiftWing ORES scores for 'Pleasanton, Iowa' with revid: 1177684203
# Getting LiftWing ORES scores for 'Pleasantville, Iowa' with revid: 1165898202
# Getting LiftWing ORES scores for 'Plover, Iowa' with revid: 1165898215
# Getting LiftWing ORES scores for 'Plymouth, Iowa' with revid: 1165898245
# Getting LiftWing ORES scores for 'Pocahontas, Iowa' with revid: 1165898276
# Getting LiftWing ORES scores for 'Polk City, Iowa' with revid: 1165898327
# Getting LiftWing ORES scores for 'Pomeroy, Iowa' with revid: 1165898357
# Getting LiftWing ORES scores for 'Popejoy, Iowa' with revid: 1165898405
# Getting LiftWing ORES scores for 'Portsmouth, Iowa' with revid: 1165898549
# Getting LiftWing ORES scores for 'Postville, Iowa' with revid: 1175385648
# Getting LiftWing ORES scores for 'Prairie City, Iowa' with revid: 1165898612
# Getting LiftWing ORES scores for 'Prairieburg, Iowa' with revid: 1165898636
# Getting LiftWing ORES scores for 'Prescott, Iowa' with revid: 1165898691
# Getting LiftWing ORES scores for 'Preston, Iowa' with revid: 1165898728
# Getting LiftWing ORES scores for 'Primghar, Iowa' with revid: 1178652426
# Getting LiftWing ORES scores for 'Princeton, Iowa' with revid: 1115660897
# Getting LiftWing ORES scores for 'Promise City, Iowa' with revid: 1165898833
# Getting LiftWing ORES scores for 'Protivin, Iowa' with revid: 1175017924
# Getting LiftWing ORES scores for 'Pulaski, Iowa' with revid: 1165898878
# Getting LiftWing ORES scores for 'Quasqueton, Iowa' with revid: 1165898987
# Getting LiftWing ORES scores for 'Quimby, Iowa' with revid: 1165899011
# Getting LiftWing ORES scores for 'Radcliffe, Iowa' with revid: 1165899057
# Getting LiftWing ORES scores for 'Rake, Iowa' with revid: 1165899073
# Getting LiftWing ORES scores for 'Ralston, Iowa' with revid: 1165899108
# Getting LiftWing ORES scores for 'Randalia, Iowa' with revid: 1165899130
# Getting LiftWing ORES scores for 'Randall, Iowa' with revid: 1165899134
# Getting LiftWing ORES scores for 'Randolph, Iowa' with revid: 1177683303
# Getting LiftWing ORES scores for 'Rathbun, Iowa' with revid: 1177078328
# Getting LiftWing ORES scores for 'Raymond, Iowa' with revid: 1165899245
# Getting LiftWing ORES scores for 'Readlyn, Iowa' with revid: 1165899288
# Getting LiftWing ORES scores for 'Reasnor, Iowa' with revid: 1165899292
# Getting LiftWing ORES scores for 'Red Oak, Iowa' with revid: 1179968516
# Getting LiftWing ORES scores for 'Redding, Iowa' with revid: 1165899331
# Getting LiftWing ORES scores for 'Redfield, Iowa' with revid: 1165899334
# Getting LiftWing ORES scores for 'Reinbeck, Iowa' with revid: 1165899425
# Getting LiftWing ORES scores for 'Rembrandt, Iowa' with revid: 1165899435
# Getting LiftWing ORES scores for 'Remsen, Iowa' with revid: 1167787836
# Getting LiftWing ORES scores for 'Renwick, Iowa' with revid: 1165899486
# Getting LiftWing ORES scores for 'Rhodes, Iowa' with revid: 1165899538
# Getting LiftWing ORES scores for 'Riceville, Iowa' with revid: 1165899568
# Getting LiftWing ORES scores for 'Richland, Iowa' with revid: 1165899619
# Getting LiftWing ORES scores for 'Rickardsville, Iowa' with revid: 1165899683
# Getting LiftWing ORES scores for 'Ricketts, Iowa' with revid: 1165899685
# Getting LiftWing ORES scores for 'Ridgeway, Iowa' with revid: 1167829662
# Getting LiftWing ORES scores for 'Rinard, Iowa' with revid: 1165899718
# Getting LiftWing ORES scores for 'Ringsted, Iowa' with revid: 1165899728
# Getting LiftWing ORES scores for 'Rippey, Iowa' with revid: 1165899769
# Getting LiftWing ORES scores for 'Riverdale, Iowa' with revid: 1135176957
# Getting LiftWing ORES scores for 'Riverside, Iowa' with revid: 1174370963
# Getting LiftWing ORES scores for 'Riverton, Iowa' with revid: 1177683346
# Getting LiftWing ORES scores for 'Robins, Iowa' with revid: 1165899914
# Getting LiftWing ORES scores for 'Rock Falls, Iowa' with revid: 1165899950
# Getting LiftWing ORES scores for 'Rock Rapids, Iowa' with revid: 1165899971
# Getting LiftWing ORES scores for 'Rock Valley, Iowa' with revid: 1165899973
# Getting LiftWing ORES scores for 'Rockford, Iowa' with revid: 1165899978
# Getting LiftWing ORES scores for 'Rockwell, Iowa' with revid: 1165900050
# Getting LiftWing ORES scores for 'Rockwell City, Iowa' with revid: 1165900044
# Getting LiftWing ORES scores for 'Rodman, Iowa' with revid: 1165900069
# Getting LiftWing ORES scores for 'Rodney, Iowa' with revid: 1165900077
# Getting LiftWing ORES scores for 'Roland, Iowa' with revid: 1165900095
# Getting LiftWing ORES scores for 'Rolfe, Iowa' with revid: 1165900100
# Getting LiftWing ORES scores for 'Rome, Iowa' with revid: 1176416091
# Getting LiftWing ORES scores for 'Rose Hill, Iowa' with revid: 1165900229
# Getting LiftWing ORES scores for 'Rossie, Iowa' with revid: 1165900299
# Getting LiftWing ORES scores for 'Rowan, Iowa' with revid: 1165900357
# Getting LiftWing ORES scores for 'Rowley, Iowa' with revid: 1165900366
# Getting LiftWing ORES scores for 'Royal, Iowa' with revid: 1165900381
# Getting LiftWing ORES scores for 'Rudd, Iowa' with revid: 1165900404
# Getting LiftWing ORES scores for 'Runnells, Iowa' with revid: 1165900440
# Getting LiftWing ORES scores for 'Russell, Iowa' with revid: 1165900482
# Getting LiftWing ORES scores for 'Ruthven, Iowa' with revid: 1165900531
# Getting LiftWing ORES scores for 'Rutland, Iowa' with revid: 1165900534
# Getting LiftWing ORES scores for 'Ryan, Iowa' with revid: 1165900549
# Getting LiftWing ORES scores for 'Sabula, Iowa' with revid: 1165900573
# Getting LiftWing ORES scores for 'Sac City, Iowa' with revid: 1128075277
# Getting LiftWing ORES scores for 'Sageville, Iowa' with revid: 1165900598
# Getting LiftWing ORES scores for 'Salem, Iowa' with revid: 1165900624
# Getting LiftWing ORES scores for 'Salix, Iowa' with revid: 1165900652
# Getting LiftWing ORES scores for 'Sanborn, Iowa' with revid: 1165900771
# Getting LiftWing ORES scores for 'Sandyville, Iowa' with revid: 1176873976
# Getting LiftWing ORES scores for 'Scarville, Iowa' with revid: 1165900971
# Getting LiftWing ORES scores for 'Schaller, Iowa' with revid: 1165900974
# Getting LiftWing ORES scores for 'Schleswig, Iowa' with revid: 1165900981
# Getting LiftWing ORES scores for 'Scranton, Iowa' with revid: 1165901074
# Getting LiftWing ORES scores for 'Searsboro, Iowa' with revid: 1168608374
# Getting LiftWing ORES scores for 'Sergeant Bluff, Iowa' with revid: 1172730298
# Getting LiftWing ORES scores for 'Seymour, Iowa' with revid: 1178624681
# Getting LiftWing ORES scores for 'Shambaugh, Iowa' with revid: 1177683696
# Getting LiftWing ORES scores for 'Shannon City, Iowa' with revid: 1165901395
# Getting LiftWing ORES scores for 'Sharpsburg, Iowa' with revid: 1165901432
# Getting LiftWing ORES scores for 'Sheffield, Iowa' with revid: 1165901492
# Getting LiftWing ORES scores for 'Shelby, Iowa' with revid: 1165901496
# Getting LiftWing ORES scores for 'Sheldahl, Iowa' with revid: 1165901527
# Getting LiftWing ORES scores for 'Sheldon, Iowa' with revid: 1165901528
# Getting LiftWing ORES scores for 'Shell Rock, Iowa' with revid: 1165901541
# Getting LiftWing ORES scores for 'Shellsburg, Iowa' with revid: 1165901550
# Getting LiftWing ORES scores for 'Shenandoah, Iowa' with revid: 1177682915
# Getting LiftWing ORES scores for 'Sherrill, Iowa' with revid: 1165901588
# Getting LiftWing ORES scores for 'Shueyville, Iowa' with revid: 1165901704
# Getting LiftWing ORES scores for 'Sibley, Iowa' with revid: 1170862863
# Getting LiftWing ORES scores for 'Sidney, Iowa' with revid: 1165901733
# Getting LiftWing ORES scores for 'Sigourney, Iowa' with revid: 1165901760
# Getting LiftWing ORES scores for 'Silver City, Iowa' with revid: 1165901796
# Getting LiftWing ORES scores for 'Sioux Center, Iowa' with revid: 1175849820
# Getting LiftWing ORES scores for 'Sioux City, Iowa' with revid: 1179868688
# Getting LiftWing ORES scores for 'Sioux Rapids, Iowa' with revid: 1170712074
# Getting LiftWing ORES scores for 'Slater, Iowa' with revid: 1155557029
# Getting LiftWing ORES scores for 'Sloan, Iowa' with revid: 1165901936
# Getting LiftWing ORES scores for 'Smithland, Iowa' with revid: 1165901976
# Getting LiftWing ORES scores for 'Soldier, Iowa' with revid: 1165902044
# Getting LiftWing ORES scores for 'Solon, Iowa' with revid: 1165902054
# Getting LiftWing ORES scores for 'Somers, Iowa' with revid: 1165902067
# Getting LiftWing ORES scores for 'South English, Iowa' with revid: 1165902183
# Getting LiftWing ORES scores for 'Spencer, Iowa' with revid: 1178254849
# Getting LiftWing ORES scores for 'Spillville, Iowa' with revid: 1165902412
# Getting LiftWing ORES scores for 'Spirit Lake, Iowa' with revid: 1165902417
# Getting LiftWing ORES scores for 'Spragueville, Iowa' with revid: 1165902638
# Getting LiftWing ORES scores for 'Spring Hill, Iowa' with revid: 1165902674
# Getting LiftWing ORES scores for 'Springbrook, Iowa' with revid: 1165902711
# Getting LiftWing ORES scores for 'Springville, Iowa' with revid: 1165902754
# Getting LiftWing ORES scores for 'St. Ansgar, Iowa' with revid: 1165902795
# Getting LiftWing ORES scores for 'St. Anthony, Iowa' with revid: 1165902799
# Getting LiftWing ORES scores for 'St. Charles, Iowa' with revid: 1165902822
# Getting LiftWing ORES scores for 'St. Donatus, Iowa' with revid: 1176593404
# Getting LiftWing ORES scores for 'St. Lucas, Iowa' with revid: 1165902911
# Getting LiftWing ORES scores for 'St. Marys, Iowa' with revid: 1165902937
# Getting LiftWing ORES scores for 'St. Olaf, Iowa' with revid: 1174966865
# Getting LiftWing ORES scores for 'St. Paul, Iowa' with revid: 1165902957
# Getting LiftWing ORES scores for 'Stacyville, Iowa' with revid: 1165902998
# Getting LiftWing ORES scores for 'Stanhope, Iowa' with revid: 1165903024
# Getting LiftWing ORES scores for 'Stanley, Iowa' with revid: 1165903028
# Getting LiftWing ORES scores for 'Stanton, Iowa' with revid: 1165903039
# Getting LiftWing ORES scores for 'Stanwood, Iowa' with revid: 1165903051
# Getting LiftWing ORES scores for 'State Center, Iowa' with revid: 1165903079
# Getting LiftWing ORES scores for 'Steamboat Rock, Iowa' with revid: 1176509984
# Getting LiftWing ORES scores for 'Stockport, Iowa' with revid: 1165903203
# Getting LiftWing ORES scores for 'Stockton, Iowa' with revid: 1165903210
# Getting LiftWing ORES scores for 'Storm Lake, Iowa' with revid: 1173446059
# Getting LiftWing ORES scores for 'Story City, Iowa' with revid: 1165903231
# Getting LiftWing ORES scores for 'Stout, Iowa' with revid: 1178489289
# Getting LiftWing ORES scores for 'Stratford, Iowa' with revid: 1165903277
# Getting LiftWing ORES scores for 'Strawberry Point, Iowa' with revid: 1165903293
# Getting LiftWing ORES scores for 'Struble, Iowa' with revid: 1165903318
# Getting LiftWing ORES scores for 'Stuart, Iowa' with revid: 1165903329
# Getting LiftWing ORES scores for 'Sully, Iowa' with revid: 1173555249
# Getting LiftWing ORES scores for 'Sumner, Iowa' with revid: 1165903428
# Getting LiftWing ORES scores for 'Superior, Iowa' with revid: 1165903491
# Getting LiftWing ORES scores for 'Sutherland, Iowa' with revid: 1165917876
# Getting LiftWing ORES scores for 'Swaledale, Iowa' with revid: 1165903531
# Getting LiftWing ORES scores for 'Swan, Iowa' with revid: 1165903536
# Getting LiftWing ORES scores for 'Swea City, Iowa' with revid: 1165903541
# Getting LiftWing ORES scores for 'Swisher, Iowa' with revid: 1169898844
# Getting LiftWing ORES scores for 'Tabor, Iowa' with revid: 1165903615
# Getting LiftWing ORES scores for 'Tama, Iowa' with revid: 1165903671
# Getting LiftWing ORES scores for 'Templeton, Iowa' with revid: 1166963544
# Getting LiftWing ORES scores for 'Tennant, Iowa' with revid: 1165903913
# Getting LiftWing ORES scores for 'Terril, Iowa' with revid: 1165903963
# Getting LiftWing ORES scores for 'Thayer, Iowa' with revid: 1165903992
# Getting LiftWing ORES scores for 'Thompson, Iowa' with revid: 1174052193
# Getting LiftWing ORES scores for 'Thor, Iowa' with revid: 1165904073
# Getting LiftWing ORES scores for 'Thornburg, Iowa' with revid: 1169234888
# Getting LiftWing ORES scores for 'Thornton, Iowa' with revid: 1165904103
# Getting LiftWing ORES scores for 'Thurman, Iowa' with revid: 1165904118
# Getting LiftWing ORES scores for 'Tiffin, Iowa' with revid: 1165904402
# Getting LiftWing ORES scores for 'Tingley, Iowa' with revid: 1165904452
# Getting LiftWing ORES scores for 'Tipton, Iowa' with revid: 1165904485
# Getting LiftWing ORES scores for 'Titonka, Iowa' with revid: 1165904513
# Getting LiftWing ORES scores for 'Toledo, Iowa' with revid: 1165904550
# Getting LiftWing ORES scores for 'Toronto, Iowa' with revid: 1165904706
# Getting LiftWing ORES scores for 'Traer, Iowa' with revid: 1165904785
# Getting LiftWing ORES scores for 'Treynor, Iowa' with revid: 1165904840
# Getting LiftWing ORES scores for 'Tripoli, Iowa' with revid: 1161273323
# Getting LiftWing ORES scores for 'Truesdale, Iowa' with revid: 1165904926
# Getting LiftWing ORES scores for 'Truro, Iowa' with revid: 1165904948
# Getting LiftWing ORES scores for 'Turin, Iowa' with revid: 1165904996
# Getting LiftWing ORES scores for 'Udell, Iowa' with revid: 1165905094
# Getting LiftWing ORES scores for 'Underwood, Iowa' with revid: 1165905151
# Getting LiftWing ORES scores for 'Union, Iowa' with revid: 1165905219
# Getting LiftWing ORES scores for 'Unionville, Iowa' with revid: 1176344089
# Getting LiftWing ORES scores for 'University Heights, Iowa' with revid: 1165905258
# Getting LiftWing ORES scores for 'University Park, Iowa' with revid: 1165905265
# Getting LiftWing ORES scores for 'Urbana, Iowa' with revid: 1165905307
# Getting LiftWing ORES scores for 'Urbandale, Iowa' with revid: 1172719626
# Getting LiftWing ORES scores for 'Ute, Iowa' with revid: 1165905939
# Getting LiftWing ORES scores for 'Vail, Iowa' with revid: 1165905957
# Getting LiftWing ORES scores for 'Valeria, Iowa' with revid: 1165905969
# Getting LiftWing ORES scores for 'Van Horne, Iowa' with revid: 1165906031
# Getting LiftWing ORES scores for 'Van Meter, Iowa' with revid: 1165906038
# Getting LiftWing ORES scores for 'Van Wert, Iowa' with revid: 1165906049
# Getting LiftWing ORES scores for 'Varina, Iowa' with revid: 1165906081
# Getting LiftWing ORES scores for 'Ventura, Iowa' with revid: 1165906111
# Getting LiftWing ORES scores for 'Victor, Iowa' with revid: 1165906210
# Getting LiftWing ORES scores for 'Villisca, Iowa' with revid: 1158263605
# Getting LiftWing ORES scores for 'Vincent, Iowa' with revid: 1165906279
# Getting LiftWing ORES scores for 'Vining, Iowa' with revid: 1165906285
# Getting LiftWing ORES scores for 'Vinton, Iowa' with revid: 1176475705
# Getting LiftWing ORES scores for 'Volga, Iowa' with revid: 1165906328
# Getting LiftWing ORES scores for 'Wadena, Iowa' with revid: 1165906372
# Getting LiftWing ORES scores for 'Wahpeton, Iowa' with revid: 1165906397
# Getting LiftWing ORES scores for 'Walcott, Iowa' with revid: 1165906413
# Getting LiftWing ORES scores for 'Walford, Iowa' with revid: 1165906447
# Getting LiftWing ORES scores for 'Walker, Iowa' with revid: 1165906471
# Getting LiftWing ORES scores for 'Wall Lake, Iowa' with revid: 1165906492
# Getting LiftWing ORES scores for 'Wallingford, Iowa' with revid: 1165906503
# Getting LiftWing ORES scores for 'Walnut, Iowa' with revid: 1165906519
# Getting LiftWing ORES scores for 'Wapello, Iowa' with revid: 1165906580
# Getting LiftWing ORES scores for 'Washington, Iowa' with revid: 1171931389
# Getting LiftWing ORES scores for 'Washta, Iowa' with revid: 1165906738
# Getting LiftWing ORES scores for 'Waterloo, Iowa' with revid: 1179869674
# Getting LiftWing ORES scores for 'Waterville, Iowa' with revid: 1175424318
# Getting LiftWing ORES scores for 'Waucoma, Iowa' with revid: 1165906819
# Getting LiftWing ORES scores for 'Waukee, Iowa' with revid: 1166519748
# Getting LiftWing ORES scores for 'Waukon, Iowa' with revid: 1165906823
# Getting LiftWing ORES scores for 'Waverly, Iowa' with revid: 1177229501
# Getting LiftWing ORES scores for 'Wayland, Iowa' with revid: 1165906889
# Getting LiftWing ORES scores for 'Webb, Iowa' with revid: 1165906940
# Getting LiftWing ORES scores for 'Webster, Iowa' with revid: 1165906956
# Getting LiftWing ORES scores for 'Webster City, Iowa' with revid: 1177296246
# Getting LiftWing ORES scores for 'Weldon, Iowa' with revid: 1165907016
# Getting LiftWing ORES scores for 'Wellman, Iowa' with revid: 1165907033
# Getting LiftWing ORES scores for 'Wellsburg, Iowa' with revid: 1165907048
# Getting LiftWing ORES scores for 'Welton, Iowa' with revid: 1165907062
# Getting LiftWing ORES scores for 'Wesley, Iowa' with revid: 1165907073
# Getting LiftWing ORES scores for 'West Bend, Iowa' with revid: 1165907091
# Getting LiftWing ORES scores for 'West Branch, Iowa' with revid: 1170747117
# Getting LiftWing ORES scores for 'West Burlington, Iowa' with revid: 1177290767
# Getting LiftWing ORES scores for 'West Chester, Iowa' with revid: 1165907116
# Getting LiftWing ORES scores for 'West Des Moines, Iowa' with revid: 1179869146
# Getting LiftWing ORES scores for 'West Liberty, Iowa' with revid: 1165907174
# Getting LiftWing ORES scores for 'West Okoboji, Iowa' with revid: 1165907196
# Getting LiftWing ORES scores for 'West Point, Iowa' with revid: 1165907211
# Getting LiftWing ORES scores for 'West Union, Iowa' with revid: 1179645217
# Getting LiftWing ORES scores for 'Westfield, Iowa' with revid: 1165907273
# Getting LiftWing ORES scores for 'Westgate, Iowa' with revid: 1165907280
# Getting LiftWing ORES scores for 'Westphalia, Iowa' with revid: 1177831524
# Getting LiftWing ORES scores for 'Westside, Iowa' with revid: 1165907344
# Getting LiftWing ORES scores for 'Westwood, Iowa' with revid: 1165907354
# Getting LiftWing ORES scores for 'What Cheer, Iowa' with revid: 1165907386
# Getting LiftWing ORES scores for 'Wheatland, Iowa' with revid: 1165907399
# Getting LiftWing ORES scores for 'Whiting, Iowa' with revid: 1165907555
# Getting LiftWing ORES scores for 'Whittemore, Iowa' with revid: 1165907565
# Getting LiftWing ORES scores for 'Whitten, Iowa' with revid: 1165907569
# Getting LiftWing ORES scores for 'Willey, Iowa' with revid: 1165907672
# Getting LiftWing ORES scores for 'Williams, Iowa' with revid: 1166205541
# Getting LiftWing ORES scores for 'Williamsburg, Iowa' with revid: 1165907712
# Getting LiftWing ORES scores for 'Williamson, Iowa' with revid: 1165907736
# Getting LiftWing ORES scores for 'Wilton, Iowa' with revid: 1179572619
# Getting LiftWing ORES scores for 'Windsor Heights, Iowa' with revid: 1178593538
# Getting LiftWing ORES scores for 'Winfield, Iowa' with revid: 1165908006
# Getting LiftWing ORES scores for 'Winterset, Iowa' with revid: 1177699843
# Getting LiftWing ORES scores for 'Winthrop, Iowa' with revid: 1165908161
# Getting LiftWing ORES scores for 'Wiota, Iowa' with revid: 1165908171
# Getting LiftWing ORES scores for 'Woden, Iowa' with revid: 1165908222
# Getting LiftWing ORES scores for 'Woodbine, Iowa' with revid: 1165908307
# Getting LiftWing ORES scores for 'Woodburn, Iowa' with revid: 1165908329
# Getting LiftWing ORES scores for 'Woodward, Iowa' with revid: 1165908462
# Getting LiftWing ORES scores for 'Woolstock, Iowa' with revid: 1157981895
# Getting LiftWing ORES scores for 'Worthington, Iowa' with revid: 1165908498
# Getting LiftWing ORES scores for 'Wyoming, Iowa' with revid: 1165908563
# Getting LiftWing ORES scores for 'Yale, Iowa' with revid: 1165908606
# Getting LiftWing ORES scores for 'Yetter, Iowa' with revid: 1165908624
# Getting LiftWing ORES scores for 'Yorktown, Iowa' with revid: 1177683758
# Getting LiftWing ORES scores for 'Zearing, Iowa' with revid: 1176797733
# Getting LiftWing ORES scores for 'Zwingle, Iowa' with revid: 1171169323
# Getting LiftWing ORES scores for 'Wichita, Kansas' with revid: 1179871048
# Getting LiftWing ORES scores for 'Overland Park, Kansas' with revid: 1176652573
# Getting LiftWing ORES scores for 'Kansas City, Kansas' with revid: 1179424676
# ...
# Getting LiftWing ORES scores for 'Granada, Minnesota' with revid: 1165748374
# Getting LiftWing ORES scores for 'Beaver Creek, Minnesota' with revid: 1165508898
# Getting LiftWing ORES scores for 'Eitzen, Minnesota' with revid: 1166392263
# Getting LiftWing ORES scores for 'Nerstrand, Minnesota' with revid: 1165895078
# Getting LiftWing ORES scores for 'Plummer, Minnesota' with revid: 1165898232
# Getting LiftWing ORES scores for 'Bowlus, Minnesota' with revid: 1167308963
# Getting LiftWing ORES scores for 'Chandler, Minnesota' with revid: 1174299948
# Getting LiftWing ORES scores for 'Vesta, Minnesota' with revid: 1165906190
# Getting LiftWing ORES scores for 'Backus, Minnesota' with revid: 1165508211
# Getting LiftWing ORES scores for 'Gonvick, Minnesota' with revid: 1165748192
# Getting LiftWing ORES scores for 'Kensington, Minnesota' with revid: 1168053988
# Getting LiftWing ORES scores for 'Wilton, Minnesota' with revid: 1165907931
# Getting LiftWing ORES scores for 'Utica, Minnesota' with revid: 1175855184
# Getting LiftWing ORES scores for 'Freeborn, Minnesota' with revid: 1165747395
# Getting LiftWing ORES scores for 'St. Hilaire, Minnesota' with revid: 1165902875
# Getting LiftWing ORES scores for 'Milroy, Minnesota' with revid: 1165893567
# Getting LiftWing ORES scores for 'Hayward, Minnesota' with revid: 1165749516
# Getting LiftWing ORES scores for 'Kelliher, Minnesota' with revid: 1167307426
# Getting LiftWing ORES scores for 'Hewitt, Minnesota' with revid: 1172394432
# Getting LiftWing ORES scores for 'Lake Wilson, Minnesota' with revid: 1174299894
# Getting LiftWing ORES scores for 'Cromwell, Minnesota' with revid: 1165645666
# Getting LiftWing ORES scores for 'Wahkon, Minnesota' with revid: 1165906391
# Getting LiftWing ORES scores for 'Climax, Minnesota' with revid: 1165644448
# Getting LiftWing ORES scores for 'Lake Lillian, Minnesota' with revid: 1177410466
# Getting LiftWing ORES scores for 'Hanley Falls, Minnesota' with revid: 1165749150
# Getting LiftWing ORES scores for 'Pease, Minnesota' with revid: 1165897424
# Getting LiftWing ORES scores for 'Oslo, Minnesota' with revid: 1165896847
# Getting LiftWing ORES scores for 'Echo, Minnesota' with revid: 1165647739
# Getting LiftWing ORES scores for 'Pemberton, Minnesota' with revid: 1165897469
# Getting LiftWing ORES scores for 'Peterson, Minnesota' with revid: 1176227310
# Getting LiftWing ORES scores for 'Gary, Minnesota' with revid: 1165747736
# Getting LiftWing ORES scores for 'Ostrander, Minnesota' with revid: 1165896861
# Getting LiftWing ORES scores for 'Ruthton, Minnesota' with revid: 1165900526
# Getting LiftWing ORES scores for 'Bigelow, Minnesota' with revid: 1165536125
# Getting LiftWing ORES scores for 'Villard, Minnesota' with revid: 1165906270
# Getting LiftWing ORES scores for 'Frost, Minnesota' with revid: 1165747475
# Getting LiftWing ORES scores for 'Gilman, Minnesota' with revid: 1175710531
# Getting LiftWing ORES scores for 'Elrosa, Minnesota' with revid: 1165650608
# Getting LiftWing ORES scores for 'Donnelly, Minnesota' with revid: 1165647011
# Getting LiftWing ORES scores for 'Dennison, Minnesota' with revid: 1165646705
# Getting LiftWing ORES scores for 'Currie, Minnesota' with revid: 1165645859
# Getting LiftWing ORES scores for 'Dalton, Minnesota' with revid: 1174371235
# Getting LiftWing ORES scores for 'Northrop, Minnesota' with revid: 1165895944
# Getting LiftWing ORES scores for 'Storden, Minnesota' with revid: 1179094387
# Getting LiftWing ORES scores for 'Rutledge, Minnesota' with revid: 1165900543
# Getting LiftWing ORES scores for 'Flensburg, Minnesota' with revid: 1174682892
# Getting LiftWing ORES scores for 'Orr, Minnesota' with revid: 1167307070
# Getting LiftWing ORES scores for 'Sobieski, Minnesota' with revid: 1165902027
# Getting LiftWing ORES scores for 'Bluffton, Minnesota' with revid: 1165536491
# Getting LiftWing ORES scores for 'Beardsley, Minnesota' with revid: 1165508831
# Getting LiftWing ORES scores for 'Lucan, Minnesota' with revid: 1165891556
# Getting LiftWing ORES scores for 'Greenwald, Minnesota' with revid: 1165748769
# Getting LiftWing ORES scores for 'Lewisville, Minnesota' with revid: 1165890109
# Getting LiftWing ORES scores for 'Ogema, Minnesota' with revid: 1165896412
# Getting LiftWing ORES scores for 'Okabena, Minnesota' with revid: 1168935781
# Getting LiftWing ORES scores for 'Garrison, Minnesota' with revid: 1178642218
# Getting LiftWing ORES scores for 'Waldorf, Minnesota' with revid: 1165906424
# Getting LiftWing ORES scores for 'Hitterdal, Minnesota' with revid: 1165750126
# Getting LiftWing ORES scores for 'Lismore, Minnesota' with revid: 1165890559
# Getting LiftWing ORES scores for 'Magnolia, Minnesota' with revid: 1165891833
# Getting LiftWing ORES scores for 'Minnesota City, Minnesota' with revid: 1165893695
# Getting LiftWing ORES scores for 'Kingston, Minnesota' with revid: 1165752257
# Getting LiftWing ORES scores for 'South Haven, Minnesota' with revid: 1165902222
# Getting LiftWing ORES scores for 'Meire Grove, Minnesota' with revid: 1174361500
# Getting LiftWing ORES scores for 'Mendota, Minnesota' with revid: 1175946257
# Getting LiftWing ORES scores for 'Hardwick, Minnesota' with revid: 1165749220
# Getting LiftWing ORES scores for 'Nelson, Minnesota' with revid: 1165895021
# Getting LiftWing ORES scores for 'Tenstrike, Minnesota' with revid: 1165903953
# Getting LiftWing ORES scores for 'Easton, Minnesota' with revid: 1165647717
# Getting LiftWing ORES scores for 'Shelly, Minnesota' with revid: 1165901553
# Getting LiftWing ORES scores for 'Holland, Minnesota' with revid: 1177405360
# Getting LiftWing ORES scores for 'Watson, Minnesota' with revid: 1172231784
# Getting LiftWing ORES scores for 'Bellechester, Minnesota' with revid: 1165509099
# Getting LiftWing ORES scores for 'Grygla, Minnesota' with revid: 1165748894
# Getting LiftWing ORES scores for 'Big Falls, Minnesota' with revid: 1165536105
# Getting LiftWing ORES scores for 'Callaway, Minnesota' with revid: 1174672122
# Getting LiftWing ORES scores for 'Lake Bronson, Minnesota' with revid: 1175371975
# Getting LiftWing ORES scores for 'Warba, Minnesota' with revid: 1165906591
# Getting LiftWing ORES scores for 'Winger, Minnesota' with revid: 1174852630
# Getting LiftWing ORES scores for 'Kettle River, Minnesota' with revid: 1171294785
# Getting LiftWing ORES scores for 'Delavan, Minnesota' with revid: 1179229249
# Getting LiftWing ORES scores for 'Felton, Minnesota' with revid: 1165746828
# Getting LiftWing ORES scores for 'Kennedy, Minnesota' with revid: 1165752017
# Getting LiftWing ORES scores for 'Dent, Minnesota' with revid: 1165646713
# Getting LiftWing ORES scores for 'Forada, Minnesota' with revid: 1165747064
# Getting LiftWing ORES scores for 'Steen, Minnesota' with revid: 1165903122
# Getting LiftWing ORES scores for 'Wright, Minnesota' with revid: 1165908535
# Getting LiftWing ORES scores for 'Palisade, Minnesota' with revid: 1165897072
# Getting LiftWing ORES scores for 'Elizabeth, Minnesota' with revid: 1165648074
# Getting LiftWing ORES scores for 'Porter, Minnesota' with revid: 1165898510
# Getting LiftWing ORES scores for 'Waltham, Minnesota' with revid: 1165906553
# Getting LiftWing ORES scores for 'Wendell, Minnesota' with revid: 1165907066
# Getting LiftWing ORES scores for 'Winton, Minnesota' with revid: 1165908168
# Getting LiftWing ORES scores for 'Iona, Minnesota' with revid: 1165750860
# Getting LiftWing ORES scores for 'Campbell, Minnesota' with revid: 1165538098
# Getting LiftWing ORES scores for 'Williams, Minnesota' with revid: 1165907696
# Getting LiftWing ORES scores for 'Longville, Minnesota' with revid: 1165891316
# Getting LiftWing ORES scores for 'Roosevelt, Minnesota' with revid: 1165900188
# Getting LiftWing ORES scores for 'Grasston, Minnesota' with revid: 1165748571
# Getting LiftWing ORES scores for 'Zumbro Falls, Minnesota' with revid: 1165908705
# Getting LiftWing ORES scores for 'Kilkenny, Minnesota' with revid: 1165752169
# Getting LiftWing ORES scores for 'Northome, Minnesota' with revid: 1170535974
# Getting LiftWing ORES scores for 'Conger, Minnesota' with revid: 1165645055
# Getting LiftWing ORES scores for 'Clements, Minnesota' with revid: 1165644343
# Getting LiftWing ORES scores for 'Kinney, Minnesota' with revid: 1174711561
# Getting LiftWing ORES scores for 'Bena, Minnesota' with revid: 1172821611
# Getting LiftWing ORES scores for 'Millville, Minnesota' with revid: 1165893547
# Getting LiftWing ORES scores for 'Mapleview, Minnesota' with revid: 1179348313
# Getting LiftWing ORES scores for 'Bellingham, Minnesota' with revid: 1165509179
# Getting LiftWing ORES scores for 'Boyd, Minnesota' with revid: 1165536776
# Getting LiftWing ORES scores for 'Blomkest, Minnesota' with revid: 1165536387
# Getting LiftWing ORES scores for 'Coates, Minnesota' with revid: 1165644576
# Getting LiftWing ORES scores for 'Laporte, Minnesota' with revid: 1166787358
# Getting LiftWing ORES scores for 'Bingham Lake, Minnesota' with revid: 1166428178
# Getting LiftWing ORES scores for 'Shevlin, Minnesota' with revid: 1165901608
# Getting LiftWing ORES scores for 'Meadowlands, Minnesota' with revid: 1165892982
# Getting LiftWing ORES scores for 'Taunton, Minnesota' with revid: 1165903733
# Getting LiftWing ORES scores for 'Elkton, Minnesota' with revid: 1165650479
# Getting LiftWing ORES scores for 'Twin Lakes, Minnesota' with revid: 1149655176
# Getting LiftWing ORES scores for 'Brook Park, Minnesota' with revid: 1165537254
# Getting LiftWing ORES scores for 'Heidelberg, Minnesota' with revid: 1165749674
# Getting LiftWing ORES scores for 'Chickamaw Beach, Minnesota' with revid: 1165539192
# Getting LiftWing ORES scores for 'Erhard, Minnesota' with revid: 1165650768
# Getting LiftWing ORES scores for 'Hammond, Minnesota' with revid: 1165749113
# Getting LiftWing ORES scores for 'Miesville, Minnesota' with revid: 1165893413
# Getting LiftWing ORES scores for 'Dunnell, Minnesota' with revid: 1165647386
# Getting LiftWing ORES scores for 'Elba, Minnesota' with revid: 1165647982
# Getting LiftWing ORES scores for 'Roscoe, Minnesota' with revid: 1172951413
# Getting LiftWing ORES scores for 'Clontarf, Minnesota' with revid: 1165644526
# Getting LiftWing ORES scores for 'Burtrum, Minnesota' with revid: 1172394416
# Getting LiftWing ORES scores for 'Federal Dam, Minnesota' with revid: 1172599587
# Getting LiftWing ORES scores for 'Foxhome, Minnesota' with revid: 1165747303
# Getting LiftWing ORES scores for 'Harding, Minnesota' with revid: 1174706995
# Getting LiftWing ORES scores for 'Lastrup, Minnesota' with revid: 1175806603
# Getting LiftWing ORES scores for 'Odin, Minnesota' with revid: 1165896369
# Getting LiftWing ORES scores for 'Wolverton, Minnesota' with revid: 1165908249
# Getting LiftWing ORES scores for 'Beaver Bay, Minnesota' with revid: 1165508891
# Getting LiftWing ORES scores for 'Garvin, Minnesota' with revid: 1165747726
# Getting LiftWing ORES scores for 'Ormsby, Minnesota' with revid: 1165896769
# Getting LiftWing ORES scores for 'Marietta, Minnesota' with revid: 1165892194
# Getting LiftWing ORES scores for 'Riverton, Minnesota' with revid: 1165899867
# Getting LiftWing ORES scores for 'Brooks, Minnesota' with revid: 1165537336
# Getting LiftWing ORES scores for 'Elmdale, Minnesota' with revid: 1174680401
# Getting LiftWing ORES scores for 'Brookston, Minnesota' with revid: 1165537350
# Getting LiftWing ORES scores for 'Biscay, Minnesota' with revid: 1165536189
# Getting LiftWing ORES scores for 'De Graff, Minnesota' with revid: 1165646299
# Getting LiftWing ORES scores for 'Avoca, Minnesota' with revid: 1165508154
# Getting LiftWing ORES scores for 'Perley, Minnesota' with revid: 1165897590
# Getting LiftWing ORES scores for 'Woodstock, Minnesota' with revid: 1165908434
# Getting LiftWing ORES scores for 'Goodridge, Minnesota' with revid: 1165748233
# Getting LiftWing ORES scores for 'Effie, Minnesota' with revid: 1174679298
# Getting LiftWing ORES scores for 'Quamba, Minnesota' with revid: 1165898981
# Getting LiftWing ORES scores for 'Iron Junction, Minnesota' with revid: 1165750897
# Getting LiftWing ORES scores for 'Mentor, Minnesota' with revid: 1165893207
# Getting LiftWing ORES scores for 'Trommald, Minnesota' with revid: 1165904886
# Getting LiftWing ORES scores for 'McKinley, St. Louis County, Minnesota' with revid: 1165892849
# Getting LiftWing ORES scores for 'Odessa, Minnesota' with revid: 1165896354
# Getting LiftWing ORES scores for 'Trosky, Minnesota' with revid: 1165904888
# Getting LiftWing ORES scores for 'Comstock, Minnesota' with revid: 1173609923
# Getting LiftWing ORES scores for 'Danvers, Minnesota' with revid: 1165646110
# Getting LiftWing ORES scores for 'Millerville, Minnesota' with revid: 1165893540
# Getting LiftWing ORES scores for 'Squaw Lake, Minnesota' with revid: 1168438167
# Getting LiftWing ORES scores for 'Alpha, Minnesota' with revid: 1165506566
# Getting LiftWing ORES scores for 'Minneiska, Minnesota' with revid: 1165893680
# Getting LiftWing ORES scores for 'Borup, Minnesota' with revid: 1165536667
# Getting LiftWing ORES scores for 'Sunburg, Minnesota' with revid: 1165903446
# Getting LiftWing ORES scores for 'Alberta, Minnesota' with revid: 1165506318
# Getting LiftWing ORES scores for 'St. Leo, Minnesota' with revid: 1165902908
# Getting LiftWing ORES scores for 'St. Anthony, Stearns County, Minnesota' with revid: 1165902803
# Getting LiftWing ORES scores for 'West Union, Minnesota' with revid: 1172518265
# Getting LiftWing ORES scores for 'Lengby, Minnesota' with revid: 1165889925
# Getting LiftWing ORES scores for 'Georgetown, Minnesota' with revid: 1165747864
# Getting LiftWing ORES scores for 'Holt, Minnesota' with revid: 1165750264
# Getting LiftWing ORES scores for 'Revere, Minnesota' with revid: 1165899510
# Getting LiftWing ORES scores for 'Arco, Minnesota' with revid: 1165507425
# Getting LiftWing ORES scores for 'Beltrami, Minnesota' with revid: 1174669371
# Getting LiftWing ORES scores for 'Holloway, Minnesota' with revid: 1165750240
# Getting LiftWing ORES scores for 'Bruno, Minnesota' with revid: 1178470316
# Getting LiftWing ORES scores for 'Bejou, Minnesota' with revid: 1165508994
# Getting LiftWing ORES scores for 'Fort Ripley, Minnesota' with revid: 1165747220
# Getting LiftWing ORES scores for 'Turtle River, Minnesota' with revid: 1165905016
# Getting LiftWing ORES scores for 'Darfur, Minnesota' with revid: 1165646167
# Getting LiftWing ORES scores for 'New Trier, Minnesota' with revid: 1165895369
# Getting LiftWing ORES scores for 'Nimrod, Minnesota' with revid: 1165895583
# Getting LiftWing ORES scores for 'Seaforth, Minnesota' with revid: 1165901128
# Getting LiftWing ORES scores for 'Bock, Minnesota' with revid: 1175717784
# Getting LiftWing ORES scores for 'Viking, Minnesota' with revid: 1165906261
# Getting LiftWing ORES scores for 'Nielsville, Minnesota' with revid: 1165895572
# Getting LiftWing ORES scores for 'Richville, Minnesota' with revid: 1165899668
# Getting LiftWing ORES scores for 'Zemple, Minnesota' with revid: 1165908695
# Getting LiftWing ORES scores for 'Dumont, Minnesota' with revid: 1165647310
# Getting LiftWing ORES scores for 'Lake Henry, Minnesota' with revid: 1165752707
# Getting LiftWing ORES scores for 'La Salle, Minnesota' with revid: 1165752545
# Getting LiftWing ORES scores for 'Solway, Minnesota' with revid: 1165902063
# Getting LiftWing ORES scores for 'Dundee, Minnesota' with revid: 1165647348
# Getting LiftWing ORES scores for 'Wanda, Minnesota' with revid: 1165906574
# Getting LiftWing ORES scores for 'Genola, Minnesota' with revid: 1165747835
# Getting LiftWing ORES scores for 'Kerrick, Minnesota' with revid: 1165752094
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-84a423895a13> in <cell line: 2>()
#       5                                        email_address="hmuppa@uw.edu",
#       6                                        access_token=ACCESS_TOKEN)
# ----> 7   for id in score['enwiki']['scores']:
#       8     pred = score['enwiki']['scores'][id]['articlequality']['score']['prediction']
#       9     quality[article_title] = pred
#
# KeyError: 'enwiki'

# %%
# Assuming you have a "quality" dictionary
quality_cities = list(quality.keys())
quality_predictions = list(quality.values())

quality_data = pd.DataFrame({'city': quality_cities, 'prediction': quality_predictions})
quality_data.to_csv("/content/drive/MyDrive/DATA_512_HW_2/processed_data/quality_predictions.csv", index=False)

# %%
import math

regions = pd.read_csv('/content/drive/MyDrive/DATA_512_HW_2/Datasets/US_States_by_Region-US_Census_Burea-Sheet1.csv')
import pandas as pd

# Assuming you have a "regions" DataFrame
regional_divisions = []
num_regions = regions.shape[0]
prev_region = ''
prev_division = ''

for i in range(num_regions):
    division = ''

    if type(regions.iloc[i]['REGION']) == str:
        division = division + str(regions.iloc[i]['REGION'])
        prev_region = regions.iloc[i]['REGION']
    else:
        division = division + str(prev_region)

    if type(regions.iloc[i]['DIVISION']) == str:
        division = division + '_' + str(regions.iloc[i]['DIVISION'])
        prev_division = regions.iloc[i]['DIVISION']
    else:
        division = division + '_' + str(prev_division)

    regional_divisions.append(division)

regions['regional_division'] = regional_divisions

state_data = regions[['STATE', 'regional_division']].dropna()

state_data.head(10)
# Out:
#             STATE           regional_division
# 2     Connecticut       Northeast_New England
# 3           Maine       Northeast_New England
# 4   Massachusetts       Northeast_New England
# 5   New Hampshire       Northeast_New England
# 6    Rhode Island       Northeast_New England
# 7         Vermont       Northeast_New England
# 9      New Jersey   Northeast_Middle Atlantic
# 10       New York   Northeast_Middle Atlantic
# 11   Pennsylvania   Northeast_Middle Atlantic
# 14       Illinois  Midwest_East North Central

# %%
# Load the predictions DataFrame from a CSV file
quality_predictions = pd.read_csv("/content/drive/MyDrive/DATA_512_HW_2/processed_data/quality_predictions.csv")

# Articles to be excluded
excluded_articles = ['2020 United States census', '2010 United States census', 'County (United States)',
                    'Population', 'Square mile', 'Federal Information Processing Standards',
                    'American National Standards Institute', 'Geographic Names Information System',
                    'Wikipedia:Citation needed']

# Remove the 'Unnamed: 0' column
quality_predictions = quality_predictions.drop("Unnamed: 0", axis=1)

# Filter out rows with articles to be excluded
filtered_predictions = quality_predictions[~quality_predictions['article'].isin(excluded_articles)]

# Extract city and state information
city_state_list = list(filtered_predictions['article'])
states = []
articles_without_state = []

for city_state in city_state_list:
    parts = city_state.split(", ")
    if len(parts) > 1:
        states.append(parts[-1])
    else:
        states.append("N/A")
        articles_without_state.append(city_state)

# %%
articles_without_state
# Out:
# ['Utqiaġvik',
#  'Los Angeles',
#  'San Diego',
#  'San Francisco',
#  'Denver',
#  'Miami',
#  'Atlanta',
#  'Echols County',
#  'Indianapolis',
#  'New Orleans',
#  'Boston',
#  'Nantucket',
#  'Detroit',
#  'Minneapolis',
#  'St. Louis',
#  'Las Vegas',
#  'New York City',
#  'Oklahoma City',
#  'Philadelphia',
#  'Pittsburgh',
#  'Grand Divisions of Tennessee',
#  'Salt Lake City',
#  'Seattle',
#  'Milwaukee']

# %%
filtered_predictions['state'] = states
# Out:
# <ipython-input-27-53f3f10584db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_predictions['state'] = states

# %%
pop_data = pd.read_excel('/content/drive/MyDrive/DATA_512_HW_2/Datasets/NST-EST2022.xlsx')
state_without_dots = []
for i in range(len(pop_data)):
  state_dot = ''.join(pop_data.iloc[i]['State'])
  state_without_dots.append(state_dot[1:])
pop_data['State'] = state_without_dots
pop_data.head()
# Out:
#         State  2022 Population
# 0     Alabama          5074296
# 1      Alaska           733583
# 2     Arizona          7359197
# 3    Arkansas          3045637
# 4  California         39029342

# %%
pred_reg = pd.merge(filtered_predictions,state_data, left_on='state',right_on='STATE',how='inner')

# %%
pred_reg.head()
# Out:
#                article prediction    state    STATE         regional_division
# 0   Abbeville, Alabama          C  Alabama  Alabama  South_East South Central
# 1  Adamsville, Alabama          C  Alabama  Alabama  South_East South Central
# 2     Addison, Alabama          C  Alabama  Alabama  South_East South Central
# 3       Akron, Alabama         GA  Alabama  Alabama  South_East South Central
# 4   Alabaster, Alabama          C  Alabama  Alabama  South_East South Central

# %%
pred_reg_pop = pd.merge(pred_reg,pop_data, left_on='state',right_on='State',how='inner')

# %%
city_ids = pd.read_json('/content/drive/MyDrive/DATA_512_HW_2/processed_data/city_data.json')
city_ids.head()
# Out:
#    pageid  ns                title contentmodel pagelanguage  \
# 0  104730   0   Abbeville, Alabama     wikitext           en
# 1  104761   0  Adamsville, Alabama     wikitext           en
# 2  105188   0     Addison, Alabama     wikitext           en
# 3  104726   0       Akron, Alabama     wikitext           en
# 4  105109   0   Alabaster, Alabama     wikitext           en
#
#   pagelanguagehtmlcode pagelanguagedir               touched   lastrevid  \
# 0                   en             ltr  2023-10-10T22:35:37Z  1171163550
# 1                   en             ltr  2023-10-10T22:35:37Z  1177621427
# 2                   en             ltr  2023-10-10T22:35:37Z  1168359898
# 3                   en             ltr  2023-10-10T22:35:37Z  1165909508
# 4                   en             ltr  2023-10-10T22:35:37Z  1179139816
#
#    length    talkid                                            fullurl  \
# 0   24706  281244.0   https://en.wikipedia.org/wiki/Abbeville,_Alabama
# 1   18040  281272.0  https://en.wikipedia.org/wiki/Adamsville,_Alabama
# 2   13309  281517.0     https://en.wikipedia.org/wiki/Addison,_Alabama
# 3   11710  281240.0       https://en.wikipedia.org/wiki/Akron,_Alabama
# 4   20343  281444.0   https://en.wikipedia.org/wiki/Alabaster,_Alabama
#
#                                              editurl  \
# 0  https://en.wikipedia.org/w/index.php?title=Abb...
# 1  https://en.wikipedia.org/w/index.php?title=Ada...
# 2  https://en.wikipedia.org/w/index.php?title=Add...
# 3  https://en.wikipedia.org/w/index.php?title=Akr...
# 4  https://en.wikipedia.org/w/index.php?title=Ala...
#
#                                         canonicalurl  watchers redirect  new
# 0   https://en.wikipedia.org/wiki/Abbeville,_Alabama       NaN      NaN  NaN
# 1  https://en.wikipedia.org/wiki/Adamsville,_Alabama       NaN      NaN  NaN
# 2     https://en.wikipedia.org/wiki/Addison,_Alabama       NaN      NaN  NaN
# 3       https://en.wikipedia.org/wiki/Akron,_Alabama       NaN      NaN  NaN
# 4   https://en.wikipedia.org/wiki/Alabaster,_Alabama       NaN      NaN  NaN

# %%
rev_ids = []
for i in range(len(pred_reg_pop)):
  art = pred_reg_pop.iloc[i]['article']
  rev_ids.append(city_ids[city_ids['title']==art].iloc[0]['lastrevid'])

# %%
pred_reg_pop['revision_id'] = rev_ids
pred_reg_pop.drop(['STATE','State'],axis=1,inplace=True)
pred_reg_pop.rename(columns={'article': 'article_title', 'prediction': 'article_quality','2022 Population':'population'}, inplace=True)
cols = ['state','regional_division','population','article_title','revision_id','article_quality']
pred_reg_pop = pred_reg_pop[cols]
pred_reg_pop.to_csv('/content/drive/MyDrive/DATA_512_HW_2/processed_data/wp_scored_city_articles_by_state.csv',index=False)
